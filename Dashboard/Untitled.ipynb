# %%
import sqlite3

# %%
connexion = sqlite3.connect("chocolate_sales.db")
curs = connexion.cursor()

# %%
import pandas as pd

# %%
pd.read_csv("./Donnees/calendar.csv")
# Out:
#            date  year  month  day  week  day_of_week
# 0    2023-01-01  2023      1    1    52            6
# 1    2023-01-02  2023      1    2     1            0
# 2    2023-01-03  2023      1    3     1            1
# 3    2023-01-04  2023      1    4     1            2
# 4    2023-01-05  2023      1    5     1            3
# ..          ...   ...    ...  ...   ...          ...
# 726  2024-12-27  2024     12   27    52            4
# 727  2024-12-28  2024     12   28    52            5
# 728  2024-12-29  2024     12   29    52            6
# 729  2024-12-30  2024     12   30     1            0
# 730  2024-12-31  2024     12   31     1            1
#
# [731 rows x 6 columns]

# %%
# !python script_base_sql.py

# %%
curs.execute("Select * from sales")

# %%
curs.execute("VACUUM;")

# %%
len(curs.fetchall())
# Out:
# 1000000

# %%
import os

os.chdir(r"C:\Users\theol\Downloads\Portfolio\Dashboard")

# %%
# !streamlit run app.py

# %%
ls .streamlit
# Out:
#  Le volume dans le lecteur C s'appelle Windows
#  Le num‚ro de s‚rie du volume est 9CEC-0CF7
#
#  R‚pertoire de C:\Users\theol\Downloads\Portfolio\Dashboard\.streamlit
#
# 11/03/2026  17:43    <DIR>          .
# 11/03/2026  17:49    <DIR>          ..
# 11/03/2026  17:43               141 config.toml
#                1 fichier(s)              141 octets
#                2 R‚p(s)  400ÿ525ÿ320ÿ192 octets libres

# %%
ls
# Out:
#  Le volume dans le lecteur C s'appelle Windows
#  Le num‚ro de s‚rie du volume est 9CEC-0CF7
#
#  R‚pertoire de C:\Users\theol\Downloads\Portfolio\Dashboard
#
# 11/03/2026  17:51    <DIR>          .
# 11/03/2026  14:46    <DIR>          ..
# 11/03/2026  17:38    <DIR>          .ipynb_checkpoints
# 11/03/2026  17:43    <DIR>          .streamlit
# 11/03/2026  17:46                43 app.py
# 11/03/2026  16:15       117ÿ370ÿ880 chocolate_sales.db
# 11/03/2026  14:47    <DIR>          Donnees
# 11/03/2026  17:46             2ÿ378 script_base_sql.py
# 11/03/2026  17:51             8ÿ330 Untitled.ipynb
#                4 fichier(s)      117ÿ381ÿ631 octets
#                5 R‚p(s)  400ÿ525ÿ254ÿ656 octets libres

# %%
curs.execute("Select * from Sales").fetchone()
# Out:
# ('0RD00000001',
#  '2023-01-07',
#  'P0080',
#  'S093',
#  'C040749',
#  5,
#  14.43,
#  0.15,
#  61.33,
#  42.77,
#  18.56)

# %%
CA = curs.execute("Select sum(REVENUE) from Sales").fetchone()[0] #CA
# Out:
# (25486128.86,)

# %%
COUTS = curs.execute("Select sum(COST) from Sales").fetchone()[0] #couts
# Out:
# (15291554.4,)

# %%
MARGE = curs.execute("Select sum(PROFIT) from Sales").fetchone()[0] #marges
# Out:
# (10194564.63,)

# %%
Avg_Discount =  curs.execute("Select sum(DISCOUNT)/count(DISCOUNT) from Sales").fetchone()[0] #marges

# %%
nb_ventes =  curs.execute("Select sum(PROFIT) from Sales").fetchone()[0] #CA

# %%
Annee = curs.execute("""Select YEAR from CALENDAR
        join SALES on SALES.ORDER_DATE = CALENDAR.Date
        WHERE SALES.ORDER_DATE = (Select MAX(SALES.ORDER_DATE) from SALES)""").fetchone()[0]

# %%
Annee = curs.execute("""Select MAX(SALES.ORDER_DATE) from SALES""").fetchone()[0]

# %%
Annee
# Out:
# '2024-12-31'

# %%
Annee_prec = 2023

# %%
CA_cur = curs.execute(f"Select sum(REVENUE) from Sales where ORDER_DATE like '{Annee}%'").fetchone()[0] #CA
CA_prec = curs.execute(f"Select sum(REVENUE) from Sales where ORDER_DATE like '{Annee_prec}%'").fetchone()[0] #CA

# %%
CA_cur
# Out:
# 12751022.59

# %%
CA_prec
# Out:
# 12735106.27

# %%
#Tops

Top_produits
Top_boutiques
Top_vendeurs

# %%
TOP_3_produits = curs.execute("""Select PRODUCTS.PRODUCT_NAME, PRODUCTS.BRAND, count(*) as NB_VENTES from Sales 
                                join PRODUCTS on Sales.PRODUCT_ID = PRODUCTS.PRODUCT_ID
                                GROUP BY Sales.PRODUCT_ID
                                ORDER BY NB_VENTES DESC
                                LIMIT 5""")

# %%
TOP_3_produits.fetchall()
# Out:
# [('Dark Chocolate 50%', 'Cadbury', 5141),
#  ('Dark Chocolate 60%', 'Cadbury', 5132),
#  ('Truffle Chocolate 80%', 'Ferrero', 5115),
#  ('White Chocolate 90%', 'Godiva', 5092),
#  ('White Chocolate 50%', 'Mars', 5089)]

# %%
curs.execute("""Select WEEK from CALENDAR
            join SALES on SALES.ORDER_DATE = CALENDAR.Date
            WHERE SALES.ORDER_DATE = (Select MAX(SALES.ORDER_DATE) from SALES)""").fetchone()[0]
# Out:
# 1

# %%
curs.execute("Select MAX(ORDER_DATE) From SALES").fetchone()
# Out:
# ('2024-12-31',)

# %%
curs.execute("Select * from CALENDAR").fetchone()
# Out:
# ('2023-01-01', 2023, 1, 1, 52, 6, '2023-00')

# %%
curs.execute("""Select sum(DISCOUNT)/count(DISCOUNT) from Sales where ORDER_DATE BETWEEN '2024-12-30' AND '2024-12-31'""").fetchone()[0]
# Out:
# 0.0529328119445432

# %%
WEEK_cur
# Out:
# '2024-53'

# %%
from openai import OpenAI

# %%
client = OpenAI( api_key= "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")

# %%
client?
# Out:
# Type:            OpenAI
# String form:     <openai.OpenAI object at 0x105ec0980>
# File:            /opt/anaconda3/envs/env_chocolate/lib/python3.14/site-packages/openai/__init__.py
# Docstring:       <no docstring>
# Class docstring:
# Abstract base class for generic types.
#
# On Python 3.12 and newer, generic classes implicitly inherit from
# Generic when they declare a parameter list after the class's name::
#
#     class Mapping[KT, VT]:
#         def __getitem__(self, key: KT) -> VT:
#             ...
#         # Etc.
#
# On older versions of Python, however, generic classes have to
# explicitly inherit from Generic.
#
# After a class has been declared to be generic, it can then be used as
# follows::
#
#     def lookup_name[KT, VT](mapping: Mapping[KT, VT], key: KT, default: VT) -> VT:
#         try:
#             return mapping[key]
#         except KeyError:
#             return default
# Init docstring:
# Construct a new synchronous OpenAI client instance.
#
# ...

# %%
client.responses.create?
# Out:
# Signature:
# client.responses.create(
#     *,
#     background: 'Optional[bool] | Omit' = <openai.Omit object at 0x108d8fcb0>,
#     context_management: 'Optional[Iterable[response_create_params.ContextManagement]] | Omit' = <openai.Omit object at 0x108d8fcb0>,
#     conversation: 'Optional[response_create_params.Conversation] | Omit' = <openai.Omit object at 0x108d8fcb0>,
#     include: 'Optional[List[ResponseIncludable]] | Omit' = <openai.Omit object at 0x108d8fcb0>,
#     input: 'Union[str, ResponseInputParam] | Omit' = <openai.Omit object at 0x108d8fcb0>,
#     instructions: 'Optional[str] | Omit' = <openai.Omit object at 0x108d8fcb0>,
#     max_output_tokens: 'Optional[int] | Omit' = <openai.Omit object at 0x108d8fcb0>,
#     max_tool_calls: 'Optional[int] | Omit' = <openai.Omit object at 0x108d8fcb0>,
#     metadata: 'Optional[Metadata] | Omit' = <openai.Omit object at 0x108d8fcb0>,
#     model: 'ResponsesModel | Omit' = <openai.Omit object at 0x108d8fcb0>,
# ...

# %%
schema = """
    TABLE SALES
    (
        ORDER_ID,
        ORDER_DATE,
        PRODUCT_ID,
        STORE_ID,
        CUSTOMER_ID,
        QUANTITY,
        UNIT_PRICE,
        DISCOUNT,
        REVENUE,
        COST,
        PROFIT
    )

    TABLE PRODUCTS
    (
        PRODUCT_ID,
        PRODUCT_NAME,
        BRAND,
        CATEGORY,
        COCOA_PERCENT,
        WEIGHT_G
    )

    TABLE STORES
    (
        STORE_ID,
        STORE_NAME,
        CITY,
        COUNTRY,
        STORE_TYPE
    )

    TABLE CUSTOMERS
    (
        CUSTOMER_ID,
        AGE,
        GENDER,
        LOYALTY_MEMBER,
        JOIN_DATE
    )

    TABLE CALENDAR
    (
        DATE,
        YEAR,
        MONTH,
        WEEK
    )
    """

prompt = f"""
    Tu es un consultant Data / BI.
    
    Tu analyses un dashboard de ventes de chocolat.
    
    Schéma :
    
    {schema}
    
    Réponds en français.
    Sois précis et orienté business.
    """
    
response = client.responses.create(
    model="gpt-5-mini",
    instructions= prompt,
    input="Quels indicateurs permettraient d'évaluer la fidélité des clients ?",
    max_output_tokens=800,
    reasoning={"effort":"medium"}
    )

response
# Out:
# Response(id='resp_07d110ec593da4f9006a3451c7cab0819fbe265ab8d9deb529', created_at=1781813703.0, error=None, incomplete_details=IncompleteDetails(reason='max_output_tokens'), instructions='\n    Tu es un consultant Data / BI.\n\n    Tu analyses un dashboard de ventes de chocolat.\n\n    Schéma :\n\n    \n    TABLE SALES\n    (\n        ORDER_ID,\n        ORDER_DATE,\n        PRODUCT_ID,\n        STORE_ID,\n        CUSTOMER_ID,\n        QUANTITY,\n        UNIT_PRICE,\n        DISCOUNT,\n        REVENUE,\n        COST,\n        PROFIT\n    )\n\n    TABLE PRODUCTS\n    (\n        PRODUCT_ID,\n        PRODUCT_NAME,\n        BRAND,\n        CATEGORY,\n        COCOA_PERCENT,\n        WEIGHT_G\n    )\n\n    TABLE STORES\n    (\n        STORE_ID,\n        STORE_NAME,\n        CITY,\n        COUNTRY,\n        STORE_TYPE\n    )\n\n    TABLE CUSTOMERS\n    (\n        CUSTOMER_ID,\n        AGE,\n        GENDER,\n        LOYALTY_MEMBER,\n        JOIN_DATE\n    )\n\n    TABLE CALENDAR\n    (\n     
# ...

# %%
low + 800 tokens, reasoning_tokens=64 mais question assez simple

# %%
print(response.output_text)
# Out:
# Voici une liste d’indicateurs pertinents pour mesurer la fidélité client, avec définitions, formules/SQL exemples adaptés à ton schéma, interprétation business et actions possibles.
#
# 1) Taux de rétention (period-over-period retention)
# - Définition : % de clients actifs sur une période T qui sont toujours actifs sur T+1.
# - Formule : retention = clients_present_both_periods / clients_in_period_T
# - SQL (ex. rétention mensuelle) :
#   SELECT c.YEAR, c.MONTH,
#     COUNT(DISTINCT s_curr.CUSTOMER_ID) AS clients_mois,
#     COUNT(DISTINCT s_prev.CUSTOMER_ID) AS clients_mois_prev,
#     COUNT(DISTINCT s_both.CUSTOMER_ID) AS clients_retenus,
#     (COUNT(DISTINCT s_both.CUSTOMER_ID)::float / NULLIF(COUNT(DISTINCT s_prev.CUSTOMER_ID),0)) AS retention_rate
#   FROM CALENDAR c
#   LEFT JOIN SALES s_curr ON DATE_TRUNC('month', s_curr.ORDER_DATE) = DATE_TRUNC('month', MAKE_DATE(c.YEAR,c.MONTH,1))
# ...

# %%
medium + 800 tokens, reasoning_tokens=768 -> None donc on doit rester sur low sinon le budget token c'est un peu n'imp vu que c'est une démo

# %%
print(response.output_text)

# %%
minimal + 800 tokens

# %%
print(response.output_text)
# Out:
# Voici une liste d’indicateurs (KPI) pertinents pour mesurer la fidélité des clients sur ton dataset de ventes de chocolat, avec formule/implémentation SQL approximative et interprétation business pour chacun.
#
# 1) Taux de rétention (retention rate)
# - Définition : % de clients ayant acheté sur une période T qui ont racheté sur la période suivante.
# - Calcul (ex. mensuel) :
#   - clients_period_t = distinct CUSTOMER_ID with ORDER_DATE in month N
#   - clients_period_t1 = distinct CUSTOMER_ID with ORDER_DATE in month N+1
#   - retained = count(distinct CUSTOMER_ID where ORDER_DATE in month N and also in month N+1)
#   - retention_rate = retained / clients_period_t
# - Interprétation : indique la capacité à conserver des clients d’un mois sur l’autre. Valeur élevée = fidélité forte.
#
# 2) Taux de churn (attrition)
# - Définition : % de clients actifs qui n’ont pas racheté sur la période suivante.
# ...

# %%
sans rien lui dire

# %%
print(response.output_text)
# Out:
# Voici une liste d’indicateurs pratiques et actionnables, avec formules/implémentations et recommandations opérationnelles, pour mesurer la fidélité client à partir de votre schéma.
#
# Principaux indicateurs (ce qu’ils mesurent et pourquoi)
# - Taux de clients récurrents (Repeat Purchase Rate)
#   - Mesure : % de clients ayant passé au moins 2 commandes sur une période.
#   - Pourquoi : indicateur simple de fidélité transactionnelle.
# - Fréquence d’achat (Purchase Frequency)
#   - Mesure : nombre moyen de commandes par client sur une période (ou commandes par client actif / année).
#   - Pourquoi : montre l’engagement régulier.
# - Récence (Recency)
#   - Mesure : temps moyen (ou médian) depuis la dernière commande.
#   - Pourquoi : plus la récence est faible, plus la probabilité de rachat est élevée.
# - Valeur client (Customer Lifetime Value, CLV)
#   - Mesure : marge nette (profit) cumulée par client ou CLV prédictif.
# ...
