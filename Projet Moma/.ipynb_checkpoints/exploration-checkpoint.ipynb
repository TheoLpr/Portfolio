# %% [markdown]
# !conda install pandas -y

# %%
import pandas as pd

# %%
artists = pd.read_csv("./Donnees/Artists.csv")
artists
# Out:
#        ConstituentID             DisplayName                  ArtistBio  \
# 0                  1          Robert Arneson        American, 1930–1992
# 1                  2          Doroteo Arnaiz         Spanish, born 1936
# 2                  3             Bill Arnold        American, born 1941
# 3                  4         Charles Arnoldi        American, born 1946
# 4                  5             Per Arnoldi          Danish, born 1941
# ...              ...                     ...                        ...
# 15633         138522           Erwin Heerich        German, 1922 – 2004
# 15634         138540    Rafael Rivera García  Puerto Rican, 1929 – 2014
# 15635         138541  Rafael López del Campo  Puerto Rican, 1936 – 2009
# 15636         138544            Efrain Lopez  Puerto Rican, 1940 – 1993
# 15637         138567            Jonas Hafner          German, born 1940
#
#         Nationality Gender  BeginDate  EndDate  Wiki QID         ULAN
# ...

# %%
artists["Wiki QID"].dropna().count()
# Out:
# np.int64(3247)

# %% [markdown]
# On vire les 2 dernièrees colonnes pck je vois pas l'intérêt wikidata est pas terrible, pas énormément d'infos à en tirer d'autant qu'il y a peu de lignes concernées

# %%
artworks = pd.read_csv("./Donnees/Artworks.csv")
artworks
# Out:
#                                                     Title  \
# 0       Ferdinandsbrücke Project, Vienna, Austria (Ele...
# 1       City of Music, National Superior Conservatory ...
# 2       Villa project, outside Vienna, Austria (Elevat...
# 3       The Manhattan Transcripts Project, New York, N...
# 4       Villa project, outside Vienna, Austria (Exteri...
# ...                                                   ...
# 157625                                           Untitled
# 157626                                           Untitled
# 157627                                           Untitled
# 157628                                           Untitled
# 157629                                           Untitled
#
#                           Artist ConstituentID  \
# 0                    Otto Wagner          6210
# 1       Christian de Portzamparc          7470
# 2                     Emil Hoppe          7605
# 3                Bernard Tschumi          7056
# ...

# %%
artworks.Dimensions.describe()
# Out:
# count                148971
# unique                91302
# top       (15.2 x 21.5 cm.)
# freq                   2457
# Name: Dimensions, dtype: object

# %%
157630 - 148971
# Out:
# 8659

# %%
artworks.columns
# Out:
# Index(['Title', 'Artist', 'ConstituentID', 'ArtistBio', 'Nationality',
#        'BeginDate', 'EndDate', 'Gender', 'Date', 'Medium', 'Dimensions',
#        'CreditLine', 'AccessionNumber', 'Classification', 'Department',
#        'DateAcquired', 'Cataloged', 'ObjectID', 'URL', 'ImageURL', 'OnView',
#        'Circumference (cm)', 'Depth (cm)', 'Diameter (cm)', 'Height (cm)',
#        'Length (cm)', 'Weight (kg)', 'Width (cm)', 'Seat Height (cm)',
#        'Duration (sec.)'],
#       dtype='str')

# %%
artworks[artworks["Dimensions"].isna()]
# Out:
#                                                     Title  \
# 77                                          Misc. objects
# 185     American System-Built Houses for The Richards ...
# 239     Sixth Street House project, Santa Monica, Cali...
# 598              Kyle Residence, Houston, Texas, Sections
# 782     Variations and Interferences of 3 Non-Homogeno...
# ...                                                   ...
# 156848           Musique Non Stop and Kraftwerk portraits
# 157503                Who Is Afraid of Ideology? Part 1-4
# 157565  Invitation card envelope from Untitled/("The h...
# 157567  Catalogue from Untitled/("The history of moder...
# 157571  Print portfolio from Untitled/("The history of...
#
#                                        Artist ConstituentID  \
# 77                   Ludwig Mies van der Rohe          7166
# 185                        Frank Lloyd Wright          6459
# 239                   Thom Mayne, Andrew Zago   8218, 22884
# ...

# %%
artworks[~artworks["OnView"].isna()]
# Out:
#                                                     Title  \
# 199       Simulated Dwelling for a Family of Five Project
# 694     Concrete Office Building Project, Berlin, Germ...
# 850     Furniture Manufacturers Association Headquarte...
# 898     Column Cover for the German Pavilion, Internat...
# 899     Column Cover for the Tugendhat House, Brno, Cz...
# ...                                                   ...
# 155309                              Study for Bigamy Hood
# 155340                                 Dataw Island, S.C.
# 155350                                     Out of the Web
# 156828                                            Veleuro
# 156856                            La conquista de América
#
#                             Artist ConstituentID  \
# 199                    David Jacob          2864
# 694       Ludwig Mies van der Rohe          7166
# 850                   Michael Webb          7987
# 898       Ludwig Mies van der Rohe          7166
# ...

# %%
artworks["Cataloged"].value_counts()
# Out:
# Cataloged
# Y    100231
# N     57399
# Name: count, dtype: int64

# %%
artworks = artworks[artworks["Cataloged"]=="Y"]

# %%
artworks[~artworks["OnView"].isna()]
# Out:
#                                                     Title  \
# 199       Simulated Dwelling for a Family of Five Project
# 694     Concrete Office Building Project, Berlin, Germ...
# 850     Furniture Manufacturers Association Headquarte...
# 898     Column Cover for the German Pavilion, Internat...
# 1063                             Carna Folding Wheelchair
# ...                                                   ...
# 153933                    Cloud-Plotting on Coenties Slip
# 153934                         Coenties Opens Out to Sea!
# 155340                                 Dataw Island, S.C.
# 155350                                     Out of the Web
# 156828                                            Veleuro
#
#                           Artist ConstituentID  \
# 199                  David Jacob          2864
# 694     Ludwig Mies van der Rohe          7166
# 850                 Michael Webb          7987
# 898     Ludwig Mies van der Rohe          7166
# ...

# %%
artworks.columns
# Out:
# Index(['Title', 'Artist', 'ConstituentID', 'ArtistBio', 'Nationality',
#        'BeginDate', 'EndDate', 'Gender', 'Date', 'Medium', 'Dimensions',
#        'CreditLine', 'AccessionNumber', 'Classification', 'Department',
#        'DateAcquired', 'Cataloged', 'ObjectID', 'URL', 'ImageURL', 'OnView',
#        'Circumference (cm)', 'Depth (cm)', 'Diameter (cm)', 'Height (cm)',
#        'Length (cm)', 'Weight (kg)', 'Width (cm)', 'Seat Height (cm)',
#        'Duration (sec.)'],
#       dtype='str')

# %%
artworks.Title.isna().value_counts()
# Out:
# Title
# False    157582
# True         48
# Name: count, dtype: int64

# %%
artworks.URL.isna().value_counts()
# Out:
# URL
# False    100231
# True      57399
# Name: count, dtype: int64

# %%
artworks.ImageURL.isna().value_counts()
# Out:
# ImageURL
# False    91043
# True     66587
# Name: count, dtype: int64

# %%
artworks.ImageURL[2]
# Out:
# 'https://www.moma.org/media/W1siZiIsIjUyNzM3NSJdLFsicCIsImNvbnZlcnQiLCItcmVzaXplIDEwMjR4MTAyNFx1MDAzZSJdXQ.jpg?sha=baf3b82af676ad45'

# %%
artworks[artworks.URL.isna()].iloc[51]
# Out:
# Title                                            Excalibur Toilet Brush
# Artist                                                  Philippe Starck
# ConstituentID                                                      8418
# ArtistBio                                           (French, born 1949)
# Nationality                                                    (French)
# BeginDate                                                        (1949)
# EndDate                                                             (0)
# Gender                                                           (male)
# Date                                                               1993
# Medium                                          Polypropylene and nylon
# Dimensions            Overall: h. 16 1/2" (41.9 cm), diam. 4 3/4" (1...
# CreditLine              David Whitney Collection, Gift of David Whitney
# AccessionNumber                                               43.2000.1
# ...

# %%
artworks[artworks.Title.isna()]
# Out:
#        Title                            Artist ConstituentID  \
# 98418    NaN                               NaN           NaN
# 98559    NaN                               NaN           NaN
# 98569    NaN                               NaN           NaN
# 98620    NaN                               NaN           NaN
# 98824    NaN                         Joe Jones          2934
# 98904    NaN                   George Maciunas         21398
# 100753   NaN                               NaN           NaN
# 100781   NaN                               NaN           NaN
# 100846   NaN                               NaN           NaN
# 100847   NaN                               NaN           NaN
# 100865   NaN  Brian Buczak, Geoffrey Hendricks   37999, 2591
# 100884   NaN                               NaN           NaN
# 100888   NaN                               NaN           NaN
# 101018   NaN                       Ben Vautier          6115
# ...

# %%
len(artworks)
# Out:
# 157630

# %% [markdown]
# Dans un premier temps afficher dans l'appli les images avec un bouton aime ou non.

# %%
pip install streamlit
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.1/9.1 MB 68.1 MB/s  0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 795.4/795.4 kB 42.2 MB/s  0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.7/4.7 MB 64.1 MB/s  0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.9/6.9 MB 67.3 MB/s  0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 34.2/34.2 MB 86.0 MB/s  0:00:00 85.4 MB/s eta 0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 15/15 [streamlit] 14/15 [streamlit]air]f]
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# !streamlit run app.py
# Out:
#       👋 Welcome to Streamlit!
#
#       If you'd like to receive helpful onboarding emails, news, offers, promotions,
#       and the occasional swag, please enter your email address below. Otherwise,
#       leave this field blank.
#
#       Email: ^C
# 2026-04-12 18:03:47.591

# %%
pip install pillow
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from PIL import Image
import requests
from io import BytesIO

image_url = 'https://www.moma.org/media/W1siZiIsIjIwNzU5MSJdLFsicCIsImNvbnZlcnQiLCItcmVzaXplIDEwMjR4MTAyNFx1MDAzZSJdXQ.jpg?sha=2b336316341a94a9'

headers = {
    "User-Agent": "Mozilla/5.0",
    "Referer": "https://www.moma.org/"
}

response = requests.get(image_url, headers=headers)

img = Image.open(BytesIO(response.content))

# %%
img
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=998x1024>

# %%
### Exploration segmentation par salle

# %%
import pandas as pd

# %%
artworks = pd.read_csv("./Donnees/Artworks.csv")
artworks = artworks[~artworks["OnView"].isna()]
artworks.OnView = artworks.OnView.str.replace('"',"")
artworks
# Out:
#                                                     Title  \
# 199       Simulated Dwelling for a Family of Five Project
# 694     Concrete Office Building Project, Berlin, Germ...
# 850     Furniture Manufacturers Association Headquarte...
# 898     Column Cover for the German Pavilion, Internat...
# 899     Column Cover for the Tugendhat House, Brno, Cz...
# ...                                                   ...
# 155309                              Study for Bigamy Hood
# 155340                                 Dataw Island, S.C.
# 155350                                     Out of the Web
# 156828                                            Veleuro
# 156856                            La conquista de América
#
#                             Artist ConstituentID  \
# 199                    David Jacob          2864
# 694       Ludwig Mies van der Rohe          7166
# 850                   Michael Webb          7987
# 898       Ludwig Mies van der Rohe          7166
# ...

# %%
artworks.columns
# Out:
# Index(['Title', 'Artist', 'ConstituentID', 'ArtistBio', 'Nationality',
#        'BeginDate', 'EndDate', 'Gender', 'Date', 'Medium', 'Dimensions',
#        'CreditLine', 'AccessionNumber', 'Classification', 'Department',
#        'DateAcquired', 'Cataloged', 'ObjectID', 'URL', 'ImageURL', 'OnView',
#        'Circumference (cm)', 'Depth (cm)', 'Diameter (cm)', 'Height (cm)',
#        'Length (cm)', 'Weight (kg)', 'Width (cm)', 'Seat Height (cm)',
#        'Duration (sec.)'],
#       dtype='str')

# %%
artworks.OnView.value_counts()
# Out:
# OnView
# "MoMA, Floor 3, 3 East"     128
# "MoMA, Floor 1, 1 South"     47
# "MoMA, Floor 5, 503"         46
# "MoMA, Floor 3, 3 South"     41
# "MoMA, Floor 5, 501"         40
#                            ...
# "MoMA, Floor 2, 210"          1
# "MoMA PS1, Third floor"       1
# "MoMA, Floor 2, 213"          1
# "MoMA, Floor 2, 204"          1
# "MoMA, Floor 2, 211"          1
# Name: count, Length: 73, dtype: int64

# %%
artworks.OnView = artworks.OnView.str.replace('"',"")

# %%
artworks.OnView.value_counts()
# Out:
# OnView
# MoMA, Floor 3, 3 East     128
# MoMA, Floor 1, 1 South     47
# MoMA, Floor 5, 503         46
# MoMA, Floor 3, 3 South     41
# MoMA, Floor 5, 501         40
#                          ...
# MoMA, Floor 2, 210          1
# MoMA PS1, Third floor       1
# MoMA, Floor 2, 213          1
# MoMA, Floor 2, 204          1
# MoMA, Floor 2, 211          1
# Name: count, Length: 73, dtype: int64

# %%
artworks.OnView.str.startswith("MoMA, Floor 2,").sum()
# Out:
# np.int64(138)

# %%
artworks[artworks["OnView"]== "MoMA, Floor 2"]
# Out:
#                                                     Title            Artist  \
# 74070                             From a Day with Juan II  Georgia O'Keeffe
# 74300                                    Bauhaus Stairway   Oskar Schlemmer
# 86428                                          Blue About     Bridget Riley
# 123434                                       Tehachapi II     Mary Heilmann
# 139343  Nick (Chateau Marmont, Los Angeles, September ...  Elizabeth Peyton
# 155340                                 Dataw Island, S.C.  Beverly Buchanan
#
#        ConstituentID              ArtistBio Nationality BeginDate EndDate  \
# 74070           4360  (American, 1887–1986)  (American)    (1887)  (1986)
# 74300           5219    (German, 1888–1943)    (German)    (1888)  (1943)
# 86428           4929   (British, born 1931)   (British)    (1931)     (0)
# 123434         30935  (American, born 1940)  (American)    (1940)     (0)
# ...

# %%
#Création de deux colonnes floor et Room pour faciliter le traitement

set(artworks.OnView)
# Out:
# {'MoMA PS1, Third floor',
#  'MoMA, Floor 1',
#  'MoMA, Floor 1, 1 South',
#  'MoMA, Floor 1, Art Lab',
#  'MoMA, Floor 1, Sculpture Garden',
#  'MoMA, Floor 2',
#  'MoMA, Floor 2, 2 South',
#  'MoMA, Floor 2, 201',
#  'MoMA, Floor 2, 202',
#  'MoMA, Floor 2, 203',
#  'MoMA, Floor 2, 204',
#  'MoMA, Floor 2, 205',
#  'MoMA, Floor 2, 206',
#  'MoMA, Floor 2, 207',
#  'MoMA, Floor 2, 208',
#  'MoMA, Floor 2, 209',
#  'MoMA, Floor 2, 210',
#  'MoMA, Floor 2, 211',
#  'MoMA, Floor 2, 213',
#  'MoMA, Floor 2, 214',
#  'MoMA, Floor 2, 215',
#  'MoMA, Floor 2, 216',
#  'MoMA, Floor 3',
#  'MoMA, Floor 3, 3 East',
#  'MoMA, Floor 3, 3 South',
#  'MoMA, Floor 4',
#  'MoMA, Floor 4, 400',
#  'MoMA, Floor 4, 401',
#  'MoMA, Floor 4, 402',
#  'MoMA, Floor 4, 403',
#  'MoMA, Floor 4, 404',
#  'MoMA, Floor 4, 405',
#  'MoMA, Floor 4, 406',
#  'MoMA, Floor 4, 407',
#  'MoMA, Floor 4, 408',
#  'MoMA, Floor 4, 409',
#  'MoMA, Floor 4, 410',
#  'MoMA, Floor 4, 412',
#  'MoMA, Floor 4, 413',
# ...

# %%
artworks[artworks['OnView'].str.startswith("MoMA, Floor 1")].OnView.value_counts()
# Out:
# OnView
# MoMA, Floor 1, 1 South             47
# MoMA, Floor 1, Sculpture Garden    16
# MoMA, Floor 1                      12
# MoMA, Floor 1, Art Lab              1
# Name: count, dtype: int64

# %%
Artlab -> Sculpture Garden

# %%
artworks[artworks['OnView'].str.startswith("MoMA, Floor 2")].OnView.value_counts()
# Out:
# OnView
# MoMA, Floor 2, 216        40
# MoMA, Floor 2, 2 South    34
# MoMA, Floor 2, 214        13
# MoMA, Floor 2, 215         8
# MoMA, Floor 2, 208         8
# MoMA, Floor 2, 203         7
# MoMA, Floor 2              6
# MoMA, Floor 2, 206         5
# MoMA, Floor 2, 209         5
# MoMA, Floor 2, 202         5
# MoMA, Floor 2, 205         5
# MoMA, Floor 2, 201         3
# MoMA, Floor 2, 207         1
# MoMA, Floor 2, 210         1
# MoMA, Floor 2, 213         1
# MoMA, Floor 2, 204         1
# MoMA, Floor 2, 211         1
# Name: count, dtype: int64

# %%
artworks[artworks['OnView'].str.startswith("MoMA, Floor 2")].OnView.value_counts().sum()
# Out:
# np.int64(144)

# %%
The David Geffen Wing 201–211 + Floor2 -> 1+1+5+8+1+5+3+5+7+1+5+7 = 49

# %%
213-216 -> 40+1+13+8 = 62
# Out:
# 89

# %%
MoMA, Floor 2, 2 South    34

# %%
artworks[artworks['OnView'].str.startswith("MoMA, Floor 3")].OnView.value_counts()
# Out:
# OnView
# MoMA, Floor 3, 3 East     128
# MoMA, Floor 3, 3 South     41
# MoMA, Floor 3               3
# Name: count, dtype: int64

# %%
Floor 3 avec South

# %%
artworks[artworks['OnView'].str.startswith("MoMA, Floor 4")].OnView.value_counts()
# Out:
# OnView
# MoMA, Floor 4, 417    35
# MoMA, Floor 4, 409    31
# MoMA, Floor 4, 402    26
# MoMA, Floor 4, 419    23
# MoMA, Floor 4, 413    18
# MoMA, Floor 4, 405    18
# MoMA, Floor 4, 420    17
# MoMA, Floor 4, 412    16
# MoMA, Floor 4, 410    16
# MoMA, Floor 4, 407    13
# MoMA, Floor 4, 406    12
# MoMA, Floor 4, 408    12
# MoMA, Floor 4, 404    11
# MoMA, Floor 4, 401    11
# MoMA, Floor 4, 416    10
# MoMA, Floor 4, 415    10
# MoMA, Floor 4, 403     6
# MoMA, Floor 4, 421     5
# MoMA, Floor 4          4
# MoMA, Floor 4, 414     3
# MoMA, Floor 4, 418     1
# MoMA, Floor 4, 400     1
# Name: count, dtype: int64

# %%
408-413 -> 31 + 12 + 16 + 16 + 18 = 93

# %%
400 - 407 + MoMA, Floor 4 = 1 + 11 + 26 + 6 + 11 + 18 + 12 + 13 = 102
# Out:
# 75

# %%
414 - 421 = 3 + 10 + 10 + 35 + 1 + 23 + 17 + 5 = 104
# Out:
# 98

# %%
# Out:
# 104

# %%
artworks[artworks['OnView'].str.startswith("MoMA, Floor 5")].OnView.value_counts()
# Out:
# OnView
# MoMA, Floor 5, 503    46
# MoMA, Floor 5, 501    40
# MoMA, Floor 5, 514    34
# MoMA, Floor 5, 521    34
# MoMA, Floor 5, 517    32
# MoMA, Floor 5, 520    31
# MoMA, Floor 5, 504    29
# MoMA, Floor 5, 511    27
# MoMA, Floor 5, 519    26
# MoMA, Floor 5, 513    24
# MoMA, Floor 5, 505    24
# MoMA, Floor 5, 516    23
# MoMA, Floor 5, 522    20
# MoMA, Floor 5, 506    20
# MoMA, Floor 5, 512    18
# MoMA, Floor 5, 510    17
# MoMA, Floor 5, 507    15
# MoMA, Floor 5, 509    15
# MoMA, Floor 5, 508    12
# MoMA, Floor 5, 502     9
# MoMA, Floor 5, 500     6
# MoMA, Floor 5          5
# MoMA, Floor 5, 523     5
# MoMA, Floor 5, 515     3
# MoMA, Floor 5, 518     1
# Name: count, dtype: int64

# %%
508 - 516 ->12 + 15 + 17 + 27 + 18 + 24 + 34 + 3 + 23 = 173

# %%
500 - 507 -> 6 + 40 + 9 + 46 + 29 + 24 + 20 + 15 = 189
# Out:
# 173

# %%
517 - 523 + MoMA, Floor 5 -> 32 + 1 + 26 + 31 + 34 + 20 + 5 + 5 = 194
# Out:
# 189

# %%
# Attribution des groupes

# %%
artworks.loc[(artworks['OnView'] == "MoMA, Floor 1") | (artworks['OnView'] == "MoMA, Floor 1, Art Lab") | (artworks['OnView'] == "MoMA, Floor 1, Sculpture Garden"), "Groupe_plan"] = "Sculpture Garden"
artworks.loc[(artworks['OnView'] == "MoMA, Floor 1, 1 South"), "Groupe_plan"] = "Design Gallery"

# %%
artworks.loc[(artworks['Groupe_plan'] == "MoMA, Floor 1, 1 South")].Classification
# Out:
# 1205      Design
# 1263      Design
# 1302      Design
# 1435      Design
# 1496      Design
# 1501      Design
# 1582      Design
# 1821      Design
# 1957      Design
# 2183      Design
# 2346      Design
# 2384      Design
# 2417      Design
# 2576      Design
# 2615      Design
# 2884      Design
# 3032      Design
# 3131      Design
# 3158      Design
# 3462      Design
# 3506      Design
# 3527      Design
# 3528      Design
# 3659      Design
# 3696      Design
# 3783      Design
# 77417     Design
# 79326     Design
# 81251     Design
# 81887     Design
# 81888     Design
# 81889     Design
# 81890     Design
# 81891     Design
# 81892     Design
# 86620     Design
# 87947     Design
# 88497     Design
# 88781     Design
# 96109     Design
# 104850    Design
# 119236    Design
# 119260    Design
# 128351     Video
# 133753    Design
# 135892    Design
# 135946    Design
# Name: Classification, dtype: str

# %%
artworks.loc[(artworks['OnView'] == "MoMA, Floor 2") | ((artworks['OnView'] >= "MoMA, Floor 2, 201") & (artworks['OnView'] <= "MoMA, Floor 2, 211")), "Groupe_plan"] = "Contemporary Art (1970–Today), North and West Galleries"
artworks.loc[((artworks['OnView'] >= "MoMA, Floor 2, 212") & (artworks['OnView'] <= "MoMA, Floor 2, 216")), "Groupe_plan"] = "Contemporary Art (1970–Today), Central Gallery"
artworks.loc[(artworks['OnView'] == "MoMA, Floor 2, South"), "Groupe_plan"] = "Contemporary Art (1970–Today), South Gallery"

# %%
artworks.loc[(artworks['Groupe_plan'] == "MoMA, Floor 2, Groupe 1")].columns
# Out:
# Index(['Title', 'Artist', 'ConstituentID', 'ArtistBio', 'Nationality',
#        'BeginDate', 'EndDate', 'Gender', 'Date', 'Medium', 'Dimensions',
#        'CreditLine', 'AccessionNumber', 'Classification', 'Department',
#        'DateAcquired', 'Cataloged', 'ObjectID', 'URL', 'ImageURL', 'OnView',
#        'Circumference (cm)', 'Depth (cm)', 'Diameter (cm)', 'Height (cm)',
#        'Length (cm)', 'Weight (kg)', 'Width (cm)', 'Seat Height (cm)',
#        'Duration (sec.)', 'Groupe_plan'],
#       dtype='str')

# %%
artworks.loc[(artworks['Groupe_plan'] == "MoMA, Floor 2, Groupe 1")]
# Out:
#                                                     Title  \
# 33702                                    Untitled (Doors)
# 49598                                            Untitled
# 73975                                             Ladybug
# 74070                             From a Day with Juan II
# 74082                                                Fire
# 74300                                    Bauhaus Stairway
# 86428                                          Blue About
# 89982                                            Untitled
# 90838                            Door: Reguliersgracht 27
# 93789                              Untitled from Untitled
# 93790                              Untitled from Untitled
# 99804                                              Sallim
# 108212  Rot-gelb-schwarzes Doppelellipsoid 'Zwilling' ...
# 109544                                               Uphe
# 109827                                Ziggurat from [2,3]
# ...

# %%
artworks.loc[(artworks['OnView'] == "MoMA, Floor 3") | (artworks['OnView'] == "MoMA, Floor 3, 3 South"), "Groupe_plan"] = "Robert Frank Gallery"
artworks.loc[(artworks['OnView'] == "MoMA, Floor 3, 3 East"), "Groupe_plan"] = "American Late 20th Century Art Gallery"

# %%
artworks.loc[(artworks['Groupe_plan'] == "MoMA, Floor 3, East")].Date.value_counts()
# Out:
# Date
# 1971                           15
# 1986                           12
# 1993                            8
# 1963                            6
# 1977                            6
# 1972                            5
# c. 1970                         5
# 1976                            4
# 1980                            4
# 1956                            2
# 1991                            2
# 1992                            2
# 1965                            2
# 1961                            2
# 1967                            2
# 1969                            2
# 1973                            2
# 1978                            2
# 1988-89                         2
# 1975                            2
# 2011 (after 1965 painting)      2
# c. 1944                         1
# 1921                            1
# 1952                            1
# 1953/1963                       1
# 1941                            1
# January-February, 1972          1
# ...

# %%
artworks.loc[(artworks['OnView'] == "MoMA, Floor 4") | ((artworks['OnView'] >= "MoMA, Floor 4, 400") & (artworks['OnView'] <= "MoMA, Floor 4, 407")), "Groupe_plan"] = "Mid-20th Century Art, North Gallery"
artworks.loc[((artworks['OnView'] >= "MoMA, Floor 4, 408") & (artworks['OnView'] <= "MoMA, Floor 4, 413")), "Groupe_plan"] = "Mid-20th Century Art, West Gallery"
artworks.loc[((artworks['OnView'] >= "MoMA, Floor 4, 414") & (artworks['OnView'] <= "MoMA, Floor 4, 421")), "Groupe_plan"] = "Mid-20th Century Art, South Gallery"

# %%
artworks.loc[(artworks['Groupe_plan'] == "Groupe 1")].Date.value_counts()
# Out:
# Date
# 1951                                                 11
# 1952                                                 10
# 1962                                                  8
# 1947                                                  6
# 1949                                                  5
# 1948                                                  4
# 1950                                                  4
# 1958                                                  4
# c. 1948                                               3
# 1959                                                  3
# 1971                                                  3
# 1982                                                  2
# 1957                                                  2
# 1960                                                  2
# 1963                                                  2
# 1974                                                  2
# 1964                                                  2
# ...

# %%
artworks.loc[(artworks['Groupe_plan'] == "Groupe 2")].Date.value_counts()
# Out:
# Date
# 1962                                  10
# 1970                                   8
# 1950                                   8
# 1959                                   6
# 1966                                   5
# 1967                                   5
# 1965                                   4
# 1956                                   3
# 1958                                   3
# 1963                                   3
# 1961                                   3
# 1964                                   3
# 1979                                   2
# 1968                                   2
# 1954                                   1
# Before 1958                            1
# 1935                                   1
# 1945                                   1
# 1938                                   1
# Spring 1958                            1
# 1947                                   1
# c. 1950                                1
# c. 1940                                1
# ...

# %%
artworks.loc[((artworks['OnView'] >= "MoMA, Floor 5, 500") & (artworks['OnView'] <= "MoMA, Floor 5, 507")), "Groupe_plan"] = "Early Modern Art, European Gallery"
artworks.loc[((artworks['OnView'] >= "MoMA, Floor 5, 508") & (artworks['OnView'] <= "MoMA, Floor 5, 516")), "Groupe_plan"] = "Early Modern Art, American Gallery"
artworks.loc[(artworks['OnView'] == "MoMA, Floor 5") | ((artworks['OnView'] >= "MoMA, Floor 5, 517") & (artworks['OnView'] <= "MoMA, Floor 5, 523")), "Groupe_plan"] = "Early Modern Art, Graphic Arts Gallery"

# %%
groupe_1 = artworks.loc[(artworks['Groupe_plan'] == "GROUPE 1")]
groupe_2 = artworks.loc[(artworks['Groupe_plan'] == "GROUPE 2")]
groupe_3 = artworks.loc[(artworks['Groupe_plan'] == "GROUPE 3")]

groupe_1.to_csv("groupe_1.csv")
groupe_2.to_csv("groupe_2.csv")
groupe_3.to_csv("groupe_3.csv")

# %%
artworks.loc[(artworks['Groupe_plan'] == "GROUPE 2")].Nationality.value_counts()
# Out:
# Nationality
# (American)          84
# (German)            32
# (French)            19
# (Dutch)              9
# (British)            6
# (Uruguayan)          4
# (Brazilian)          4
# (Russian)            3
# ()                   2
# (Spanish)            2
# (Argentine)          2
# (Swedish)            1
# (Swiss)              1
# (Italian)            1
# (Belgian)            1
# (French) (Swiss)     1
# (Cuban)              1
# Name: count, dtype: int64

# %%
artworks.loc[(artworks['Groupe_plan'] == "GROUPE 3")].Nationality.value_counts()
# Out:
# Nationality
# (American)                   68
# ()                           29
# (Spanish)                    14
# (British)                     6
# (Swiss)                       6
# (Italian)                     5
# (Mexican)                     5
# (Japanese)                    5
# (French)                      4
# (German)                      4
# (Belgian)                     3
# (American) (American)         2
# (Dutch)                       1
# (Canadian)                    1
# (Trinidad and Tobagonian)     1
# Name: count, dtype: int64

# %%
import pandas as pd
artworks = pd.read_csv("./Donnees/Artworks.csv")
artworks = artworks[~artworks["OnView"].isna()]
artworks.OnView = artworks.OnView.str.replace('"',"")
artworks
# Out:
#                                                     Title  \
# 199       Simulated Dwelling for a Family of Five Project
# 694     Concrete Office Building Project, Berlin, Germ...
# 850     Furniture Manufacturers Association Headquarte...
# 898     Column Cover for the German Pavilion, Internat...
# 899     Column Cover for the Tugendhat House, Brno, Cz...
# ...                                                   ...
# 155309                              Study for Bigamy Hood
# 155340                                 Dataw Island, S.C.
# 155350                                     Out of the Web
# 156828                                            Veleuro
# 156856                            La conquista de América
#
#                             Artist ConstituentID  \
# 199                    David Jacob          2864
# 694       Ludwig Mies van der Rohe          7166
# 850                   Michael Webb          7987
# 898       Ludwig Mies van der Rohe          7166
# ...

# %%
artworks.loc[(artworks['OnView'] == "MoMA, Floor 1") | (artworks['OnView'] == "MoMA, Floor 1, Art Lab") | (artworks['OnView'] == "MoMA, Floor 1, Sculpture Garden"), "Groupe_plan"] = "Sculpture Garden"
artworks.loc[(artworks['OnView'] == "MoMA, Floor 1, 1 South"), "Groupe_plan"] = "Design Gallery"

artworks.loc[(artworks['OnView'] == "MoMA, Floor 2") | ((artworks['OnView'] >= "MoMA, Floor 2, 201") & (artworks['OnView'] <= "MoMA, Floor 2, 211")), "Groupe_plan"] = "Contemporary Art (1970–Today), North and West Galleries"
artworks.loc[((artworks['OnView'] >= "MoMA, Floor 2, 212") & (artworks['OnView'] <= "MoMA, Floor 2, 216")), "Groupe_plan"] = "Contemporary Art (1970–Today), Central Gallery"
artworks.loc[(artworks['OnView'] == "MoMA, Floor 2, 2 South"), "Groupe_plan"] = "Contemporary Art (1970–Today), South Gallery"

artworks.loc[(artworks['OnView'] == 'MoMA PS1, Third floor') | (artworks['OnView'] == "MoMA, Floor 3") | (artworks['OnView'] == "MoMA, Floor 3, 3 South"), "Groupe_plan"] = "Robert Frank Gallery"
artworks.loc[(artworks['OnView'] == "MoMA, Floor 3, 3 East"), "Groupe_plan"] = "American Late 20th Century Art Gallery"

artworks.loc[(artworks['OnView'] == "MoMA, Floor 4") | ((artworks['OnView'] >= "MoMA, Floor 4, 400") & (artworks['OnView'] <= "MoMA, Floor 4, 407")), "Groupe_plan"] = "Mid-20th Century Art, North Gallery"
artworks.loc[((artworks['OnView'] >= "MoMA, Floor 4, 408") & (artworks['OnView'] <= "MoMA, Floor 4, 413")), "Groupe_plan"] = "Mid-20th Century Art, West Gallery"
artworks.loc[((artworks['OnView'] >= "MoMA, Floor 4, 414") & (artworks['OnView'] <= "MoMA, Floor 4, 421")), "Groupe_plan"] = "Mid-20th Century Art, South Gallery"

artworks.loc[((artworks['OnView'] >= "MoMA, Floor 5, 500") & (artworks['OnView'] <= "MoMA, Floor 5, 507")), "Groupe_plan"] = "Early Modern Art, European Gallery"
artworks.loc[((artworks['OnView'] >= "MoMA, Floor 5, 508") & (artworks['OnView'] <= "MoMA, Floor 5, 516")), "Groupe_plan"] = "Early Modern Art, American Gallery"
artworks.loc[(artworks['OnView'] == "MoMA, Floor 5") | ((artworks['OnView'] >= "MoMA, Floor 5, 517") & (artworks['OnView'] <= "MoMA, Floor 5, 523")), "Groupe_plan"] = "Early Modern Art, Graphic Arts Gallery"

artworks.loc[artworks['OnView'] == "MoMA, Floor 6", "Groupe_plan"] = "Thomas Schütte Gallery"

# %%
artworks.loc[:,"Groupe_plan"].value_counts().sum()
# Out:
# np.int64(1210)

# %%
artworks.OnView.str.startswith("MoMA, Floor 1").sum()
# Out:
# np.int64(76)

# %%
(artworks.Groupe_plan == "Sculpture Garden").sum() + (artworks.Groupe_plan == "Design Gallery").sum()
# Out:
# np.int64(76)

# %%
artworks.OnView.str.startswith("MoMA, Floor 2").sum()
# Out:
# np.int64(144)

# %%
(artworks.Groupe_plan == "Contemporary Art (1970–Today), North and West Galleries").sum() + (artworks.Groupe_plan == "Contemporary Art (1970–Today), Central Gallery").sum() + (artworks.Groupe_plan =="Contemporary Art (1970–Today), South Gallery").sum()
# Out:
# np.int64(144)

# %%
artworks.OnView.str.startswith("MoMA, Floor 3").sum()
# Out:
# np.int64(172)

# %%
(artworks.Groupe_plan =="Robert Frank Gallery").sum() + (artworks.Groupe_plan =="American Late 20th Century Art Gallery").sum()
# Out:
# np.int64(172)

# %%
artworks.OnView.str.startswith("MoMA, Floor 4").sum()
# Out:
# np.int64(299)

# %%
(artworks.Groupe_plan =="Mid-20th Century Art, North Gallery").sum() + (artworks.Groupe_plan =="Mid-20th Century Art, West Gallery").sum() + (artworks.Groupe_plan =="Mid-20th Century Art, South Gallery").sum()
# Out:
# np.int64(299)

# %%
artworks.OnView.str.startswith("MoMA, Floor 5").sum()
# Out:
# np.int64(516)

# %%
(artworks.Groupe_plan =="Early Modern Art, European Gallery").sum() + (artworks.Groupe_plan =="Early Modern Art, American Gallery").sum() + (artworks.Groupe_plan =="Early Modern Art, Graphic Arts Gallery").sum()
# Out:
# np.int64(516)

# %%
artworks = artworks.reset_index(drop=True)
artworks
# Out:
#                                                   Title  \
# 0       Simulated Dwelling for a Family of Five Project
# 1     Concrete Office Building Project, Berlin, Germ...
# 2     Furniture Manufacturers Association Headquarte...
# 3     Column Cover for the German Pavilion, Internat...
# 4     Column Cover for the Tugendhat House, Brno, Cz...
# ...                                                 ...
# 1205                              Study for Bigamy Hood
# 1206                                 Dataw Island, S.C.
# 1207                                     Out of the Web
# 1208                                            Veleuro
# 1209                            La conquista de América
#
#                           Artist ConstituentID  \
# 0                    David Jacob          2864
# 1       Ludwig Mies van der Rohe          7166
# 2                   Michael Webb          7987
# 3       Ludwig Mies van der Rohe          7166
# 4       Ludwig Mies van der Rohe          7166
# ...

# %%
group_names = set(artworks.Groupe_plan)

# %%
effectifs = {group : (artworks.Groupe_plan ==group).sum() for group in group_names}
effectifs
# Out:
# {'Mid-20th Century Art, North Gallery': np.int64(102),
#  'Sculpture Garden': np.int64(29),
#  'Mid-20th Century Art, South Gallery': np.int64(104),
#  'Early Modern Art, American Gallery': np.int64(173),
#  'Early Modern Art, Graphic Arts Gallery': np.int64(154),
#  'Contemporary Art (1970–Today), Central Gallery': np.int64(62),
#  'Contemporary Art (1970–Today), North and West Galleries': np.int64(48),
#  'Early Modern Art, European Gallery': np.int64(189),
#  'Contemporary Art (1970–Today), South Gallery': np.int64(34),
#  'American Late 20th Century Art Gallery': np.int64(128),
#  'Thomas Schütte Gallery': np.int64(2),
#  'Robert Frank Gallery': np.int64(45),
#  'Mid-20th Century Art, West Gallery': np.int64(93),
#  'Design Gallery': np.int64(47)}

# %%
artworks[artworks["Groupe_plan"] == "Early Modern Art, American Gallery"].index
# Out:
# Index([   1,    3,    4,   10,   27,   29,   30,   31,   33,   34,
#        ...
#         969, 1007, 1046, 1070, 1071, 1072, 1104, 1139, 1201, 1202],
#       dtype='int64', length=173)

# %%
resampled = artworks.groupby("Groupe_plan").sample(n=189, replace=True)

# %%
effectifs_resampled = {group : (resampled.Groupe_plan ==group).sum() for group in group_names}
effectifs_resampled
# Out:
# {'Mid-20th Century Art, North Gallery': np.int64(189),
#  'Sculpture Garden': np.int64(189),
#  'Mid-20th Century Art, South Gallery': np.int64(189),
#  'Early Modern Art, American Gallery': np.int64(189),
#  'Early Modern Art, Graphic Arts Gallery': np.int64(189),
#  'Contemporary Art (1970–Today), Central Gallery': np.int64(189),
#  'Contemporary Art (1970–Today), North and West Galleries': np.int64(189),
#  'Early Modern Art, European Gallery': np.int64(189),
#  'Contemporary Art (1970–Today), South Gallery': np.int64(189),
#  'American Late 20th Century Art Gallery': np.int64(189),
#  'Thomas Schütte Gallery': np.int64(189),
#  'Robert Frank Gallery': np.int64(189),
#  'Mid-20th Century Art, West Gallery': np.int64(189),
#  'Design Gallery': np.int64(189)}

# %%
for group in group_names:
    artworks[artworks["Groupe_plan"]==group].to_csv(f'{group}.csv')

# %%
artistes_a_mettre_en_avant = {'American Late 20th Century Art Gallery' : ["Yayoi Kusama", "Rosemarie Trockel", "Adrian Piper"],
'Contemporary Art (1970–Today), Central Gallery' : ["Cai Guo-Qiang", "Louise Lawler"],
'Contemporary Art (1970–Today), North and West Galleries' : ["Georgia O'Keeffe", "Joan Mitchell", "Bridget Riley"],
'Contemporary Art (1970–Today), South Gallery' : ["Pablo Picasso", "Paul Cézanne", "Henri Matisse"],
'Design Gallery' : ["Charles Eames, Ray Eames", "Isamu Noguchi", "Philippe Starck"],
'Early Modern Art, American Gallery' : ["Piet Mondrian", "Constantin Brâncuși", "Ellsworth Kelly"],
'Early Modern Art, European Gallery' : ["Henri Matisse", "Pablo Picasso", "Gustav Klimt"],
'Early Modern Art, Graphic Arts Gallery' : ["Pablo Picasso", "Salvador Dalí", "René Magritte"],
'Mid-20th Century Art, North Gallery' : ["Mark Rothko", "Jackson Pollock", "Louise Bourgeois"],
'Mid-20th Century Art, South Gallery' : ["Yoko Ono", "Le Corbusier (Charles-Édouard Jeanneret)", "Marlene Dumas"],
'Mid-20th Century Art, West Gallery' : ["Andy Warhol", "On Kawara", "Harry Callahan"],
'Robert Frank Gallery' : ["Robert Frank", "James Turrell"],
'Sculpture Garden' : ["Henri Matisse", "Pablo Picasso", "Rachel Whiteread"],
'Thomas Schütte Gallery' : ["Thomas Schütte"]
}

# %%
for group in group_names:
    for name in artistes_a_mettre_en_avant[group] :
        if name not in set(resampled[resampled["Groupe_plan"] == group].Artist):
            print(group, name, set(resampled[resampled["Groupe_plan"] == group].Artist), '\n\n\n')

# %%
len(resampled)
# Out:
# 2646

# %%
2926

# %%
for group in group_names:
    upsample = resampled.loc[((resampled["Groupe_plan"] == group) & (resampled["Artist"].isin(artistes_a_mettre_en_avant[group]))),:].sample(n= 20, replace=True)
    resampled = pd.concat([resampled, upsample])

# %%
len(resampled)
# Out:
# 2926

# %%
group_names
# Out:
# {'American Late 20th Century Art Gallery',
#  'Contemporary Art (1970–Today), Central Gallery',
#  'Contemporary Art (1970–Today), North and West Galleries',
#  'Contemporary Art (1970–Today), South Gallery',
#  'Design Gallery',
#  'Early Modern Art, American Gallery',
#  'Early Modern Art, European Gallery',
#  'Early Modern Art, Graphic Arts Gallery',
#  'Mid-20th Century Art, North Gallery',
#  'Mid-20th Century Art, South Gallery',
#  'Mid-20th Century Art, West Gallery',
#  'Robert Frank Gallery',
#  'Sculpture Garden',
#  'Thomas Schütte Gallery'}

# %%
import pandas as pd

artworks = pd.read_csv("./Donnees/Artworks.csv")
artworks = artworks[~artworks["OnView"].isna()]
artworks = artworks[~artworks.ImageURL.isna()].reset_index(drop = True)

artworks.OnView = artworks.OnView.str.replace('"',"")

artworks.loc[(artworks['OnView'] == "MoMA, Floor 1") | (artworks['OnView'] == "MoMA, Floor 1, Art Lab") | (artworks['OnView'] == "MoMA, Floor 1, Sculpture Garden"), "Zone"] = "Sculpture Garden"
artworks.loc[(artworks['OnView'] == "MoMA, Floor 1, 1 South"), "Zone"] = "Design Gallery"

artworks.loc[(artworks['OnView'] == "MoMA, Floor 2") | ((artworks['OnView'] >= "MoMA, Floor 2, 201") & (artworks['OnView'] <= "MoMA, Floor 2, 211")), "Zone"] = "Contemporary Art, North and West Galleries"
artworks.loc[((artworks['OnView'] >= "MoMA, Floor 2, 212") & (artworks['OnView'] <= "MoMA, Floor 2, 216")), "Zone"] = "Contemporary Art, Central Gallery"
artworks.loc[(artworks['OnView'] == "MoMA, Floor 2, 2 South"), "Zone"] = "Contemporary Art, South Gallery"

artworks.loc[(artworks['OnView'] == 'MoMA PS1, Third floor') | (artworks['OnView'] == "MoMA, Floor 3") | (artworks['OnView'] == "MoMA, Floor 3, 3 South"), "Zone"] = "Robert Frank Gallery"
artworks.loc[(artworks['OnView'] == "MoMA, Floor 3, 3 East"), "Zone"] = "American Late 20th Century Art Gallery"

artworks.loc[(artworks['OnView'] == "MoMA, Floor 4") | ((artworks['OnView'] >= "MoMA, Floor 4, 400") & (artworks['OnView'] <= "MoMA, Floor 4, 407")), "Zone"] = "Mid-20th Century Art, North Gallery"
artworks.loc[((artworks['OnView'] >= "MoMA, Floor 4, 408") & (artworks['OnView'] <= "MoMA, Floor 4, 413")), "Zone"] = "Mid-20th Century Art, West Gallery"
artworks.loc[((artworks['OnView'] >= "MoMA, Floor 4, 414") & (artworks['OnView'] <= "MoMA, Floor 4, 421")), "Zone"] = "Mid-20th Century Art, South Gallery"

artworks.loc[((artworks['OnView'] >= "MoMA, Floor 5, 500") & (artworks['OnView'] <= "MoMA, Floor 5, 507")), "Zone"] = "Early Modern Art, European Gallery"
artworks.loc[((artworks['OnView'] >= "MoMA, Floor 5, 508") & (artworks['OnView'] <= "MoMA, Floor 5, 516")), "Zone"] = "Early Modern Art, American Gallery"
artworks.loc[(artworks['OnView'] == "MoMA, Floor 5") | ((artworks['OnView'] >= "MoMA, Floor 5, 517") & (artworks['OnView'] <= "MoMA, Floor 5, 523")), "Zone"] = "Early Modern Art, Graphic Arts Gallery"

artworks.loc[artworks['OnView'] == "MoMA, Floor 6", "Zone"] = "Thomas Schütte Gallery"



artworks.loc[(artworks['Zone'] == "Sculpture Garden"), "Groupe"] = "Sculpture Garden"
artworks.loc[(artworks['Zone'] == "Design Gallery"), "Groupe"] = "Design"
artworks.loc[(artworks['Zone'] == "Contemporary Art, North and West Galleries") | (artworks['Zone'] == "Contemporary Art, Central Gallery") | (artworks['Zone'] == "Contemporary Art, South Gallery"), "Groupe"] = "Contemporary Art"
artworks.loc[(artworks['Zone'] == "Mid-20th Century Art, North Gallery") | (artworks['Zone'] == "Mid-20th Century Art, West Gallery") | (artworks['Zone'] == "Mid-20th Century Art, South Gallery"), "Groupe"] = "Mid-20th Century Art"
artworks.loc[(artworks['Zone'] == "Early Modern Art, European Gallery") | (artworks['Zone'] == "Early Modern Art, American Gallery") | (artworks['Zone'] == "Early Modern Art, Graphic Arts Gallery"), "Groupe"] = "Early Modern Art"
artworks.loc[(artworks['Zone'] == "Thomas Schütte Gallery"), "Groupe"] = "Thomas Schütte"
artworks.loc[(artworks['Zone'] == "Robert Frank Gallery"), "Groupe"] = "Robert Frank"
artworks.loc[(artworks['Zone'] == "American Late 20th Century Art Gallery") , "Groupe"] = "American Late 20th Century Art"



resampled_artworks = artworks.groupby("Zone").sample(n=185, replace=True)
resampled_artworks = resampled_artworks.reset_index(drop=True)

a_afficher = pd.DataFrame(columns = resampled_artworks.columns)
for groupe in set(resampled_artworks["Groupe"]):
    print(groupe)
    for _ in range(2) :
        
        object_id = np.random.choice(resampled_artworks[resampled_artworks["Groupe"] == groupe].ObjectID, size = 1)[0]
        a_afficher = pd.concat([a_afficher, resampled_artworks[resampled_artworks["ObjectID"] == object_id].drop_duplicates()])
        resampled_artworks = resampled_artworks[resampled_artworks["ObjectID"] != object_id]

for _ in range(9):
        object_id = np.random.choice(resampled_artworks.ObjectID, size = 1)[0]
        a_afficher = pd.concat([a_afficher, resampled_artworks[resampled_artworks["ObjectID"] == object_id].drop_duplicates()])
        resampled_artworks = resampled_artworks[resampled_artworks["ObjectID"] != object_id]

# %%
resampled_artworks.columns
# Out:
# Index(['Title', 'Artist', 'ConstituentID', 'ArtistBio', 'Nationality',
#        'BeginDate', 'EndDate', 'Gender', 'Date', 'Medium', 'Dimensions',
#        'CreditLine', 'AccessionNumber', 'Classification', 'Department',
#        'DateAcquired', 'Cataloged', 'ObjectID', 'URL', 'ImageURL', 'OnView',
#        'Circumference (cm)', 'Depth (cm)', 'Diameter (cm)', 'Height (cm)',
#        'Length (cm)', 'Weight (kg)', 'Width (cm)', 'Seat Height (cm)',
#        'Duration (sec.)', 'Zone', 'Groupe'],
#       dtype='str')

# %%
resampled_artworks
# Out:
#                        Title                      Artist ConstituentID  \
# 0                   Untitled           Birgit Jürgenssen         30952
# 1                   Untitled           Birgit Jürgenssen         30952
# 2      Juvenile Sex Symbol 3                     Jo Baer           281
# 3     Food for the Spirit #4                Adrian Piper          7017
# 4                M.R.M (Sex)  Claude Cahun (Lucy Schwob)          8195
# ...                      ...                         ...           ...
# 2585    Hauptstadt (Capital)              Thomas Schütte          5281
# 2586    Hauptstadt (Capital)              Thomas Schütte          5281
# 2587    Hauptstadt (Capital)              Thomas Schütte          5281
# 2588                 Krieger              Thomas Schütte          5281
# 2589    Hauptstadt (Capital)              Thomas Schütte          5281
#
#                   ArtistBio Nationality BeginDate EndDate    Gender  \
# ...

# %%
artworks.Zone.value_counts()
# Out:
# Zone
# Early Modern Art, European Gallery            185
# Early Modern Art, American Gallery            167
# Early Modern Art, Graphic Arts Gallery        153
# American Late 20th Century Art Gallery        110
# Mid-20th Century Art, North Gallery           100
# Mid-20th Century Art, South Gallery            94
# Mid-20th Century Art, West Gallery             83
# Contemporary Art, Central Gallery              57
# Design Gallery                                 46
# Contemporary Art, North and West Galleries     46
# Robert Frank Gallery                           42
# Contemporary Art, South Gallery                34
# Sculpture Garden                               28
# Thomas Schütte Gallery                          2
# Name: count, dtype: int64

# %%
resampled_artworks.Zone.value_counts() / len(resampled_artworks)
# Out:
# Zone
# American Late 20th Century Art Gallery        0.071429
# Contemporary Art, Central Gallery             0.071429
# Contemporary Art, North and West Galleries    0.071429
# Contemporary Art, South Gallery               0.071429
# Design Gallery                                0.071429
# Early Modern Art, American Gallery            0.071429
# Early Modern Art, European Gallery            0.071429
# Early Modern Art, Graphic Arts Gallery        0.071429
# Mid-20th Century Art, North Gallery           0.071429
# Mid-20th Century Art, South Gallery           0.071429
# Mid-20th Century Art, West Gallery            0.071429
# Robert Frank Gallery                          0.071429
# Sculpture Garden                              0.071429
# Thomas Schütte Gallery                        0.071429
# Name: count, dtype: float64

# %%
resampled_artworks = artworks.groupby("Zone").sample(n=185, replace=True)

# %%
resampled_artworks.Groupe.value_counts() / len(resampled_artworks)
# Out:
# Groupe
# Contemporary Art                  0.214286
# Early Modern Art                  0.214286
# Mid-20th Century Art              0.214286
# American Late 20th Century Art    0.071429
# Design                            0.071429
# Robert Frank                      0.071429
# Sculpture Garden                  0.071429
# Thomas Schütte                    0.071429
# Name: count, dtype: float64

# %%
resampled_artworks = resampled_artworks.reset_index(drop=True)

# %%
resampled_artworks.columns
# Out:
# Index(['Title', 'Artist', 'ConstituentID', 'ArtistBio', 'Nationality',
#        'BeginDate', 'EndDate', 'Gender', 'Date', 'Medium', 'Dimensions',
#        'CreditLine', 'AccessionNumber', 'Classification', 'Department',
#        'DateAcquired', 'Cataloged', 'ObjectID', 'URL', 'ImageURL', 'OnView',
#        'Circumference (cm)', 'Depth (cm)', 'Diameter (cm)', 'Height (cm)',
#        'Length (cm)', 'Weight (kg)', 'Width (cm)', 'Seat Height (cm)',
#        'Duration (sec.)', 'Zone', 'Groupe'],
#       dtype='str')

# %%
len(set(resampled_artworks.ObjectID)) == len(resampled_artworks.drop_duplicates())
# Out:
# True

# %%
resampled_artworks
# Out:
# Empty DataFrame
# Columns: [Title, Artist, ConstituentID, ArtistBio, Nationality, BeginDate, EndDate, Gender, Date, Medium, Dimensions, CreditLine, AccessionNumber, Classification, Department, DateAcquired, Cataloged, ObjectID, URL, ImageURL, OnView, Circumference (cm), Depth (cm), Diameter (cm), Height (cm), Length (cm), Weight (kg), Width (cm), Seat Height (cm), Duration (sec.), Zone, Groupe]
# Index: []
#
# [0 rows x 32 columns]

# %%
import numpy as np

# %%
# Out:
# Early Modern Art
# Thomas Schütte
# Robert Frank
# Mid-20th Century Art
# Sculpture Garden
# Contemporary Art
# American Late 20th Century Art
# Design

# %%
len(a_afficher)
# Out:
# 16

# %%
a_afficher
# Out:
#                                                   Title  \
# 1157                I See Again in Memory My Dear Udnie
# 1312  The Negro press was also influential in urging...
# 2407                               Hauptstadt (Capital)
# 2405                                            Krieger
# 2059                                       Coney Island
# 2036                                              Laura
# 1619                                       Family, Peru
# 1740                                           Untitled
# 2239  Entrance Gate to Paris Subway (Métropolitain) ...
# 2234                                       The Back (I)
# 393                                 Ziggurat from [2,3]
# 595                                     Child with Bird
# 35                                               Flower
# 59    Untitled from the series Most Definitely Not P...
# 776                                    Chronotime Clock
# 845                                        Coat Hangers
# ...

# %%
resampled_artworks[resampled_artworks["ObjectID"] == object_id].drop_duplicates()
# Out:
#                           Title         Artist ConstituentID  \
# 770  Tulip Armchair (model 150)  Eero Saarinen          5103
#
#                                ArtistBio Nationality BeginDate EndDate  \
# 770  (American, born Finland. 1910–1961)  (American)    (1910)  (1961)
#
#      Gender     Date                                             Medium  ...  \
# 770  (male)  1955-56  Fiberglass-reinforced polyester and cast aluminum  ...
#
#     Depth (cm) Diameter (cm) Height (cm) Length (cm) Weight (kg) Width (cm)  \
# 770    59.6901           NaN     80.0102         NaN         NaN    64.1351
#
#     Seat Height (cm)  Duration (sec.)            Zone  Groupe
# 770              NaN              NaN  Design Gallery  Design
#
# [1 rows x 32 columns]

# %%
object_id
# Out:
# np.int64(78549)

# %%
resampled_artworks["ObjectID"]
# Out:
# 0        52049
# 1       160207
# 2       420267
# 3       473023
# 4       420272
#          ...
# 2585    219627
# 2586    159919
# 2587    219627
# 2588    159919
# 2589    159919
# Name: ObjectID, Length: 2590, dtype: int64

# %%
object_id in resampled_artworks[resampled_artworks["Groupe"] == "Early Modern Art"].ObjectID
# Out:
# False

# %%
resampled_artworks[resampled_artworks["ObjectID"] == 293592].Groupe
# Out:
# 1854    Mid-20th Century Art
# 1936    Mid-20th Century Art
# 2027    Mid-20th Century Art
# Name: Groupe, dtype: str

# %%
(a_afficher.groupby("Groupe").count()["Title"] / a_afficher.groupby("Groupe").count()["Title"]).head(3).index
# Out:
# Index(['American Late 20th Century Art', 'Contemporary Art', 'Design'], dtype='str', name='Groupe')
